# %% [markdown]
# # Werkverdeling
# ## Diaz
# Diaz was verantwoordelijk voor de algemene coördinatie van het project, hierbij heeft Diaz het werk verdeeld onder de groepsleden, deadlines bijgehouden en afspraken gemaakt. Daarnaast heeft Diaz zich gericht op het vinden van geschikte datasets, het uitvoeren van de preprocessing van die datasets, het creëren van de visualisaties en het structureren van de website.
#
# ## Kars
# Kars was betrokken bij het creëren van de  Daarnaast heeft Kars ook geholpen aan het vormgeven van de algemene verhaallijn van de data story project, zoals het helpen vormgeven van de perspectieven en de argumenten zelf. Tot slot heeft Kars de conclusie geschreven
#
#
# ## Liam
# Liam heeft meegewerkt aan het uitwerken van de argumenten voor beide perspectieven. Hij hielp bij het formuleren van de kernpunten en dacht mee over welke gegevens en grafieken het beste gebruikt konden worden om de standpunten te ondersteunen. Daarnaast heeft Liam meegeholpen bij het uitwerken van de argumentatie, zodat dit overzichtelijk leesbaar was.
#
#
# ## Thomas
# Thomas heeft meegewerkt aan het schrijven van de introductie, de reflectie en heeft de werkverdeling gemaakt. Daarnaast heeft Thomas ook meegeholpen met het verbeteren van de algemene structuur van het project.
