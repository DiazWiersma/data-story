# %% [markdown]
# # Remote Work in Data: Efficiënter Werken of Teamspirit Verliezen?
# Studenten: Liam Boesten (15819965), Diaz Wiersma (15379078), Thomas Driesen (15831876), Kars Koopmanschap (15691241)
#
# Team nummer: 19

# %% [markdown]
# ## Introductie

# %% [markdown]
# ## Dataset en Preprocessing

# %% [markdown]
# ## De kracht van remote werken

# %% [markdown]
# ### Hogere zelfgerapporteerde productiviteit

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# CSV inlezen
df = pd.read_csv("/Users/diazwiersma/data-story/docs/Graphs/remote_work_productivity.csv")

# Gemiddelde productivity per Employment_Type
avg_productivity = df.groupby('Employment_Type')['Productivity_Score'].mean()

# Bar chart
avg_productivity.plot(kind='bar', color=['skyblue', 'salmon'])
plt.title("Gemiddelde Productiviteit: Remote vs Office")
plt.ylabel("Productivity Score")
plt.xlabel("Employment Type")
plt.ylim(0, 100)
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# > *Figuur 1: gemiddelde "Productivity Score" van zowel In-Office als Remote medewerkers*

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/Users/diazwiersma/data-story/docs/Graphs/The Impacts of Working Remotely and in an Office Survey.csv")

# Bereken percentages
perc_yes = (df["Do you think that working from home increases your work productivity?"] == "Yes").mean() * 100
perc_no = 100 - perc_yes

# Labels en waarden voor de legenda
labels = ["Ja", "Nee"]
sizes = [perc_yes, perc_no]
colors = ['salmon', 'skyblue']

plt.figure(figsize=(6,6))
wedges, texts, autotexts = plt.pie(
    sizes, 
    colors=colors, 
    autopct='%1.1f%%', 
    startangle=90, 
    textprops={'fontsize': 12}
)

plt.title("Denk je dat werken vanuit huis je productiviteit op werk verhoogt?")
plt.axis('equal')  # Cirkelvormig

# Legenda toevoegen
plt.legend(wedges, labels, title="Antwoorden", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))

plt.tight_layout()
plt.show()

# %% [markdown]
# > *Figuur 2: Perceptie van respondenten over de invloed van thuiswerken op productiviteit*

# %% [markdown]
# Nam eget dui. Etiam rhoncus. Maecenas tempus, tellus eget condimentum rhoncus, sem quam semper libero, sit amet adipiscing sem neque sed ipsum. Nam quam nunc, blandit vel, luctus pulvinar, hendrerit id, lorem. Maecenas nec odio et ante tincidunt tempus. Donec vitae sapien ut libero venenatis faucibus. Nullam quis ante.

# %% [markdown]
# ### Minder stress, betere mentale gezondheid en betere wellbeing

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Laad dataset
df = pd.read_csv('/Users/diazwiersma/data-story/docs/Graphs/Impact_of_Remote_Work_on_Mental_Health.csv')

# Normaliseer kolomnamen en waarden
df.columns = df.columns.str.strip()
df['Work_Location'] = df['Work_Location'].str.strip().str.capitalize()
df['Stress_Level'] = df['Stress_Level'].str.strip().str.capitalize()
df['Mental_Health_Condition'] = df['Mental_Health_Condition'].fillna('None').str.strip().str.capitalize()
df['Sleep_Quality'] = df['Sleep_Quality'].str.strip().str.capitalize()

# Welzijnsindicatoren
locations = df['Work_Location'].unique()
indicators = ['Lage stress', 'Geen mentale aandoening', 'Goede slaapkwaliteit']
data = []

for location in locations:
    subset = df[df['Work_Location'] == location]
    total = len(subset)
    low_stress = (subset['Stress_Level'] == 'Low').sum() / total * 100
    no_mental_issue = (subset['Mental_Health_Condition'] == 'None').sum() / total * 100
    good_sleep = (subset['Sleep_Quality'] == 'Good').sum() / total * 100
    data.append([low_stress, no_mental_issue, good_sleep])

# Transponeer
data = np.array(data).T  # 3 x n matrix
y = np.arange(len(locations))
bar_height = 0.2
colors = ['mediumseagreen', 'cornflowerblue', 'gold']

# Plot
plt.figure(figsize=(10, 6))

for i in range(len(indicators)):
    bars = plt.barh(y + i * bar_height, data[i], height=bar_height, label=indicators[i], color=colors[i])
    for bar in bars:
        width = bar.get_width()
        plt.text(width + 1, bar.get_y() + bar.get_height()/2,
                 f'{width:.1f}%', va='center', fontsize=9)

# Styling
plt.xlabel("Percentage respondenten")
plt.ylabel("Werklocatie")
plt.xlim(0, 100)
plt.yticks(y + bar_height, locations)
plt.title("Welzijnsindicatoren per werklocatie")
plt.legend()
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# > *Figuur 3: Vergelijking van welzijnsindicatoren tussen remote, onsite en hybride werkers*

# %% [markdown]
# Stijgende voedselprijzen raken dus niet iedereen even hard. In rijke huishoudens is voedsel een klein deel van het budget. In arme gezinnen is dat vaak meer dan 50%. Inflatie vergroot zo de ongelijkheid, zonder gerichte maatregelen dreigt basisvoeding onbetaalbaar te worden voor een groeiende groep mensen.

# %%
df = pd.read_csv("/Users/diazwiersma/data-story/docs/Graphs/remote_work_productivity.csv")

# Gemiddelde productivity per Employment_Type
avg_productivity = df.groupby('Employment_Type')['Well_Being_Score'].mean()

# Bar chart
avg_productivity.plot(kind='bar', color=['skyblue', 'salmon'])
plt.title("Gemiddeld Welzijn: Remote vs Office")
plt.ylabel("Well Being Score")
plt.xlabel("Employment Type")
plt.ylim(0, 100)
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# > *Figuur 4: gemiddelde "Well Being Score" van zowel In-Office als Remote medewerkers*

# %% [markdown]
# ## Your Second Perspective

# %% [markdown]
# Lorem ipsum dolor sit amet, consectetuer adipiscing elit. Aenean commodo ligula eget dolor. Aenean massa. Cum sociis natoque penatibus et magnis dis parturient montes, nascetur ridiculus mus. Donec quam felis, ultricies nec, pellentesque eu, pretium quis, sem. Nulla consequat massa quis enim. Donec pede justo, fringilla vel, aliquet nec, vulputate eget, arcu.

# %% [markdown]
# ### Mensen kunnen meer uren op kantoor werken

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/diazwiersma/data-story/docs/Graphs/remote_work_productivity.csv")


sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x="Hours_Worked_Per_Week",
    y="Well_Being_Score",
    hue="Employment_Type",
    palette={"Remote": "skyblue", "In-Office": "salmon"},
    alpha=0.7,
    edgecolor="w",
    s=100
)

plt.title("Werktijd vs. Welzijnsscore per Werkvorm", fontsize=14)
plt.xlabel("Uren gewerkt per week", fontsize=12)
plt.ylabel("Welzijnsscore", fontsize=12)
plt.legend(title="Werkvorm")
plt.tight_layout()

plt.show()

# %% [markdown]
# > *Figuur 3: Overzicht volatiliteit voedselprijzen per land en jaar*

# %%
import plotly.express as px
df = pd.read_csv("/Users/diazwiersma/data-story/docs/Graphs/remote_work_impact.csv")

# Verdeling social isolation rating per werkplek
fig1 = px.histogram(df, x='Social_Isolation_Rating', color='Work_Location', barmode='group',
                    title='Verdeling van Sociale Isolatie per Werkplek',
                    labels={'Social_Isolation_Rating': 'Social Isolation Rating',
                            'count': 'Aantal Respondenten'},
                    color_discrete_map={'Remote': '#636EFA', 'Office': '#EF553B'})
fig1.show()


# Boxplot: Social Isolation per Work Location
fig2 = px.box(df, x='Work_Location', y='Social_Isolation_Rating',
              color='Work_Location',
              title='Social Isolation Rating per Work Location',
              labels={'Social_Isolation_Rating': 'Social Isolation Rating', 'Work_Location': 'Werkplek'},
              color_discrete_map={'Remote': '#636EFA', 'Office': '#EF553B'})
fig2.update_layout(showlegend=False)
fig2.show()


# Scatterplot Social Isolation vs Stress Level (indien Stress_Level al numeriek is)
if 'Stress_Level_Num' in df.columns:
    fig3 = px.scatter(df, x='Social_Isolation_Rating', y='Stress_Level_Num', color='Work_Location',
                      title='Social Isolation vs Stress Level',
                      labels={'Social_Isolation_Rating': 'Social Isolation Rating',
                              'Stress_Level_Num': 'Stress Level'},
                      color_discrete_map={'Remote': '#636EFA', 'Office': '#EF553B'},
                      trendline='ols')
    fig3.show()
else:
    print("Stress_Level_Num kolom niet gevonden, maak deze eerst numeriek.")


# Boxplot: Social Isolation per Productivity Change
fig4 = px.box(df, x='Productivity_Change', y='Social_Isolation_Rating',
              color='Work_Location',
              title='Social Isolation per Productivity Change',
              labels={'Productivity_Change': 'Productivity Change', 'Social_Isolation_Rating': 'Social Isolation Rating'},
              category_orders={'Productivity_Change': ['Increase', 'No Change', 'Decrease']},
              color_discrete_map={'Remote': '#636EFA', 'Office': '#EF553B'})
fig4.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 import plotly.express as px
# ----> 2 df = pd.read_csv("/Users/diazwiersma/data-story/docs/Graphs/remote_work_impact.csv")
#       4 # Verdeling social isolation rating per werkplek
#       5 fig1 = px.histogram(df, x='Social_Isolation_Rating', color='Work_Location', barmode='group',
#       6                     title='Verdeling van Sociale Isolatie per Werkplek',
#       7                     labels={'Social_Isolation_Rating': 'Social Isolation Rating',
#       8                             'count': 'Aantal Respondenten'},
#       9                     color_discrete_map={'Remote': '#636EFA', 'Office': '#EF553B'})
#
# ...

# %% [markdown]
# ## References
# Sonntag, A. (n.d.). The right to food. Welthungerhilfe.de - Für Eine Welt Ohne Hunger Und Armut. https://www.welthungerhilfe.org/our-work/focus-areas/partnering-with-civil-society/right-to-food#:~:text=Every%20human%20has%20the%20right%20to%20adequate%2C%20sufficient%2C,protect%20and%20ensure%20the%20human%20right%20to%20food.![image.png](attachment:a206e171-f8ff-4ac9-b35e-7b396eaea816.png)![image.png](attachment:5da1980b-e64b-48e1-8142-35b3aa8df1a6.png)![image.png](attachment:2778cfbf-216c-455b-a1a0-7320a6c31e91.png)![image.png](attachment:446c427c-95be-4af4-8070-a932c02cd72a.png)
